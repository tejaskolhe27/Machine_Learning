# %% [markdown]
# #### **Bundus Bank Seasonal ARIMA**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
bund = pd.read_csv("BUNDESBANK-BBK01_WT5511.csv",index_col=0)
bund.head()
# Out:
#             Value
# Date
# 30-04-1968  39.10
# 31-05-1968  42.00
# 30-06-1968  40.95
# 31-07-1968  38.90
# 31-08-1968  39.85

# %%
idx=pd.to_datetime(bund.index)
bund.index=idx
bund.head()
# Out:
# /tmp/ipykernel_199155/2909901978.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   idx=pd.to_datetime(bund.index)
#             Value
# Date
# 1968-04-30  39.10
# 1968-05-31  42.00
# 1968-06-30  40.95
# 1968-07-31  38.90
# 1968-08-31  39.85

# %%
y = bund['Value']
y_train = y[:-6]
y_test = y[-6:]

# %%
from pmdarima.arima import auto_arima

# %%
model = auto_arima(y_train, trace=True,
                   error_action='ignore', 
                   suppress_warnings=True,
                  seasonal= True,m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=3.22 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5685.919, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=5682.975, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5682.375, Time=0.71 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=5685.643, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=5680.751, Time=0.24 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=5682.347, Time=0.65 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=5683.125, Time=1.15 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=5682.083, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=5681.760, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=5681.456, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=5683.409, Time=0.61 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=5680.967, Time=0.10 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12] intercept
# Total fit time: 7.826 seconds

# %%
forecast = model.predict(n_periods=len(y_test))
forecast = pd.DataFrame(forecast,index = y_test.index,
                        columns=['Prediction'])

# %%
#plot the predictions for validation set
plt.plot(y_train, label='Train',color="blue")
plt.plot(y_test, label='Valid',color="pink")
plt.plot(forecast, label='Prediction',color="purple")
plt.legend(loc='best')
plt.show()

# %%
# plot results
plt.plot(y_test)
plt.plot(forecast, color='red')
plt.show()

# %%
rms = sqrt(mean_squared_error(y_test, forecast))
print('Test RMSE: %.3f' % rms)
# Out:
# Test RMSE: 78.204

# %%
#### Building model on the whole data
model = auto_arima(y, trace=True, error_action='ignore', 
                   suppress_warnings=True,seasonal=True,m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=5748.671, Time=3.08 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5759.940, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=5757.601, Time=0.47 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5757.111, Time=0.72 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=5759.885, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=5750.079, Time=2.65 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=5749.816, Time=2.87 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=5750.384, Time=6.44 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=5750.434, Time=6.25 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=5750.261, Time=1.38 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=5750.426, Time=5.91 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=5750.929, Time=5.66 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=5752.506, Time=6.97 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=5758.790, Time=2.42 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=5758.758, Time=2.67 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=5747.615, Time=4.01 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=5747.834, Time=3.26 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=5747.613, Time=3.26 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=5745.888, Time=1.71 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=5760.322, Time=0.73 sec
#  ARIMA(4,1,2)(0,0,0)[12] intercept   : AIC=5744.485, Time=1.80 sec
#  ARIMA(4,1,2)(1,0,0)[12] intercept   : AIC=5746.367, Time=3.74 sec
#  ARIMA(4,1,2)(0,0,1)[12] intercept   : AIC=5746.284, Time=3.10 sec
#  ARIMA(4,1,2)(1,0,1)[12] intercept   : AIC=5747.470, Time=4.54 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=5761.411, Time=0.79 sec
#  ARIMA(5,1,2)(0,0,0)[12] intercept   : AIC=5741.794, Time=2.52 sec
#  ARIMA(5,1,2)(1,0,0)[12] intercept   : AIC=5742.110, Time=3.91 sec
#  ARIMA(5,1,2)(0,0,1)[12] intercept   : AIC=5742.344, Time=2.35 sec
#  ARIMA(5,1,2)(1,0,1)[12] intercept   : AIC=5741.148, Time=4.35 sec
#  ARIMA(5,1,2)(2,0,1)[12] intercept   : AIC=5742.703, Time=8.30 sec
#  ARIMA(5,1,2)(1,0,2)[12] intercept   : AIC=5742.696, Time=7.66 sec
#  ARIMA(5,1,2)(0,0,2)[12] intercept   : AIC=5742.339, Time=6.65 sec
#  ARIMA(5,1,2)(2,0,0)[12] intercept   : AIC=5741.906, Time=7.59 sec
#  ARIMA(5,1,2)(2,0,2)[12] intercept   : AIC=5744.786, Time=9.12 sec
#  ARIMA(5,1,1)(1,0,1)[12] intercept   : AIC=5749.134, Time=3.83 sec
#  ARIMA(5,1,3)(1,0,1)[12] intercept   : AIC=5738.515, Time=4.96 sec
#  ARIMA(5,1,3)(0,0,1)[12] intercept   : AIC=5739.391, Time=4.38 sec
#  ARIMA(5,1,3)(1,0,0)[12] intercept   : AIC=5738.972, Time=4.49 sec
#  ARIMA(5,1,3)(2,0,1)[12] intercept   : AIC=5740.362, Time=9.26 sec
#  ARIMA(5,1,3)(1,0,2)[12] intercept   : AIC=5739.998, Time=8.68 sec
#  ARIMA(5,1,3)(0,0,0)[12] intercept   : AIC=5738.042, Time=2.49 sec
#  ARIMA(4,1,3)(0,0,0)[12] intercept   : AIC=5745.501, Time=1.87 sec
#  ARIMA(5,1,4)(0,0,0)[12] intercept   : AIC=inf, Time=2.87 sec
#  ARIMA(4,1,4)(0,0,0)[12] intercept   : AIC=5744.612, Time=2.36 sec
#  ARIMA(5,1,3)(0,0,0)[12]             : AIC=5737.014, Time=1.21 sec
#  ARIMA(5,1,3)(1,0,0)[12]             : AIC=5737.795, Time=2.54 sec
#  ARIMA(5,1,3)(0,0,1)[12]             : AIC=5737.962, Time=2.82 sec
#  ARIMA(5,1,3)(1,0,1)[12]             : AIC=5736.791, Time=3.34 sec
#  ARIMA(5,1,3)(2,0,1)[12]             : AIC=5738.253, Time=5.96 sec
#  ARIMA(5,1,3)(1,0,2)[12]             : AIC=5738.168, Time=5.42 sec
#  ARIMA(5,1,3)(0,0,2)[12]             : AIC=5737.965, Time=4.22 sec
#  ARIMA(5,1,3)(2,0,0)[12]             : AIC=5737.601, Time=4.90 sec
#  ARIMA(5,1,3)(2,0,2)[12]             : AIC=5740.310, Time=6.96 sec
#  ARIMA(4,1,3)(1,0,1)[12]             : AIC=5747.249, Time=3.07 sec
#  ARIMA(5,1,2)(1,0,1)[12]             : AIC=5741.291, Time=2.91 sec
#  ARIMA(5,1,4)(1,0,1)[12]             : AIC=inf, Time=4.39 sec
#  ARIMA(4,1,2)(1,0,1)[12]             : AIC=5745.944, Time=3.36 sec
#  ARIMA(4,1,4)(1,0,1)[12]             : AIC=inf, Time=3.89 sec
#
# Best model:  ARIMA(5,1,3)(1,0,1)[12]
# Total fit time: 227.222 seconds

# %%
import numpy as np
forecast = model.predict(n_periods=6)
#forecast = pd.DataFrame(forecast,index = np.arange(y.shape[0]+1,y.shape[0]+7),
                       # columns=['Prediction'])

#plot the predictions for validation set
plt.plot(y, label='Train',color="red")

plt.plot(forecast, label='Prediction',color="green")
plt.show()
