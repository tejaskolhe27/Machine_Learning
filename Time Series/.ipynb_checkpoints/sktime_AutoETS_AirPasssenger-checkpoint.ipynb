# %%
import os
import numpy as np
import pandas as pd

from sktime.utils.plotting import plot_series
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.ets import AutoETS
from sktime.forecasting.base import ForecastingHorizon
from sktime.performance_metrics.forecasting import mean_squared_error
from sktime.forecasting.exp_smoothing import ExponentialSmoothing

# %%
df=pd.read_csv("gdp-per-capita-ppp-constant-2011.csv",index_col=0)
df.head()
# Out:
#       GDP per capita, PPP (constant 2011 international $)
# Year
# 1990                                           1754.857
# 1991                                           1737.615
# 1992                                           1796.532
# 1993                                           1845.149
# 1994                                           1930.113

# %%
idx=pd.PeriodIndex(df.index,freq='Y')
df.index=idx
df.head()
# Out:
#       GDP per capita, PPP (constant 2011 international $)
# Year
# 1990                                           1754.857
# 1991                                           1737.615
# 1992                                           1796.532
# 1993                                           1845.149
# 1994                                           1930.113

# %%
df.shape
# Out:
# (28, 1)

# %%
plot_series(df)
# Out:
# (<Figure size 1600x400 with 1 Axes>, <Axes: >)

# %%
y=df['GDP per capita, PPP (constant 2011 international $)']
y_train,y_test=temporal_train_test_split(y,test_size=6)
print(y_train.shape,y_test.shape)
# Out:
# (22,) (6,)

# %%
plot_series(y_train,y_test,labels=['y_train','y_test'])
# Out:
# (<Figure size 1600x400 with 1 Axes>, <Axes: >)

# %%
# Specifying Forecasting Horizon

# %%
## Exponential Smoothing
import matplotlib.pyplot as plt

# %%
fh=ForecastingHorizon(y_test.index,is_relative=False)
fh
# Out:
# ForecastingHorizon(['2012', '2013', '2014', '2015', '2016', '2017'], dtype='period[A-DEC]', is_relative=False)

# %%
forecaster=AutoETS(auto=True,sp=1)
forecaster.fit(y_train)
print(forecaster.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   22
# Model:                       ETS(MAN)   Log Likelihood                -121.458
# Date:                Fri, 17 Nov 2023   AIC                            252.916
# Time:                        06:46:01   BIC                            258.371
# Sample:                    12-31-1990   HQIC                           254.201
#                          - 12-31-2011   Scale                            0.001
# Covariance Type:               approx
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# smoothing_level     0.9928      0.277      3.586      0.000       0.450       1.535
# smoothing_trend     0.4938      0.237      2.081      0.037       0.029       0.959
# initial_level    1729.6040     46.592     37.123      0.000    1638.286    1820.922
# initial_trend      23.7455     47.815      0.497      0.619     -69.970     117.461
# ===================================================================================
# Ljung-Box (Q):                        1.67   Jarque-Bera (JB):                 2.19
# Prob(Q):                              0.43   Prob(JB):                         0.33
# Heteroskedasticity (H):               1.95   Skew:                            -0.68
# Prob(H) (two-sided):                  0.40   Kurtosis:                         2.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %%
y_pred=forecaster.predict(fh)
plot_series(y_train,y_test,y_pred,labels=['y_train','y_test','Y_pred'])
plt.show()

# %%
mean_squared_error(y_test,y_pred,square_root=True)
# Out:
# 131.95694729893737
