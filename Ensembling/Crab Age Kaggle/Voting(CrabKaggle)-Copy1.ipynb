# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split,KFold,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import accuracy_score,log_loss
from sklearn.pipeline import Pipeline
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
crab=pd.read_csv("crab_train.csv",index_col=0)
crab.head()
# Out:
#    Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# id
# 0    I  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1    I  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2    M  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3    F  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4    I  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#     Shell Weight  Age
# id
# 0       8.348928    9
# 1       3.401940    8
# 2       6.662133    9
# 3      14.996885   11
# 4       5.953395    8

# %%
X=crab.drop("Age",axis=1)
y=crab['Age']

# %%
kfold=KFold(n_splits=5,shuffle=True,random_state=23)

# %%
cat=CatBoostRegressor(random_state=23,cat_features=['Sex'])
params={'max_depth':[2,3,4,5,6,None],
        'learning_rate':np.linspace(0.001,0.999,10),
        'n_estimators':[50,100,150]}
kfold=KFold(n_splits=5,shuffle=True,random_state=23)

# %%
gcv=GridSearchCV(cat,param_grid=params,cv=kfold,scoring="r2",verbose=1)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# 0:	learn: 3.1767346	total: 59.3ms	remaining: 2.91s
# 1:	learn: 3.1755627	total: 67.3ms	remaining: 1.61s
# 2:	learn: 3.1744370	total: 76.1ms	remaining: 1.19s
# 3:	learn: 3.1732591	total: 82.8ms	remaining: 953ms
# 4:	learn: 3.1720851	total: 91.2ms	remaining: 821ms
# 5:	learn: 3.1708852	total: 98.4ms	remaining: 721ms
# 6:	learn: 3.1697510	total: 106ms	remaining: 649ms
# 7:	learn: 3.1685778	total: 112ms	remaining: 586ms
# 8:	learn: 3.1673911	total: 118ms	remaining: 538ms
# 9:	learn: 3.1662239	total: 125ms	remaining: 499ms
# 10:	learn: 3.1650504	total: 132ms	remaining: 468ms
# 11:	learn: 3.1639154	total: 138ms	remaining: 436ms
# 12:	learn: 3.1627506	total: 143ms	remaining: 407ms
# 13:	learn: 3.1615993	total: 148ms	remaining: 381ms
# 14:	learn: 3.1604531	total: 153ms	remaining: 357ms
# 15:	learn: 3.1592946	total: 159ms	remaining: 338ms
# 16:	learn: 3.1581371	total: 165ms	remaining: 320ms
# ...

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)

# %% [markdown]
# ### LGBoost

# %%
xgb=XGBRegressor(random_state=23,cat_features=['Sex'])
params={'max_depth':[2,3,4,5,6,None],
        'learning_rate':np.linspace(0.001,0.999,10),
        'n_estimators':[50,100,150]}
kfold=KFold(n_splits=5,shuffle=True,random_state=23)

# %%
gcv_xgb=GridSearchCV(cat,param_grid=params,cv=kfold,scoring="r2",verbose=1)
gcv_xgb.fit(X,y)

# %%
print("best parameter :",gcv_xgb.best_params_)
print("best score :",gcv_xgb.best_score_

# %% [markdown]
# ### Light GBM

# %%
lgb=LGBMRegressor(random_state=23,cat_features=['Sex'])
params={'max_depth':[2,3,4,5,6,None],
        'learning_rate':np.linspace(0.001,0.999,10),
        'n_estimators':[50,100,150]}
kfold=KFold(n_splits=5,shuffle=True,random_state=23)

# %%
gcv_lgb=GridSearchCV(cat,param_grid=params,cv=kfold,scoring="r2",verbose=1)
gcv_lgb.fit(X,y)

# %%
print("best parameter :",gcv_lgb.best_params_)
print("best score :",gcv_lgb.best_score_
