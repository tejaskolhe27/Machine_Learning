# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler,MinMaxScaler
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,StratifiedKFold,GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,log_loss
from sklearn.tree import DecisionTreeClassifier

# %%
image=pd.read_csv("Image_Segmention.csv")
image.head()
# Out:
#        Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0  BRICKFACE                  188                  133                   9
# 1  BRICKFACE                  105                  139                   9
# 2  BRICKFACE                   34                  137                   9
# 3  BRICKFACE                   39                  111                   9
# 4  BRICKFACE                   16                  128                   9
#
#    short.line.density.5  short.line.density.2  vedge.mean  vegde.sd  \
# 0                   0.0                   0.0    0.333333  0.266667
# 1                   0.0                   0.0    0.277778  0.107407
# 2                   0.0                   0.0    0.500000  0.166667
# 3                   0.0                   0.0    0.722222  0.374074
# 4                   0.0                   0.0    0.500000  0.077778
#
#    hedge.mean  hedge.sd  intensity.mean  rawred.mean  rawblue.mean  \
# 0    0.500000  0.077778        6.666666     8.333334      7.777778
# 1    0.833333  0.522222        6.111111     7.555555      7.222222
# 2    1.111111  0.474074        5.851852     7.777778      6.444445
# 3    0.888889  0.429629        6.037037     7.000000      7.666666
# 4    0.666667  0.311111        5.555555     6.888889      6.666666
#
#    rawgreen.mean  exred.mean  exblue.mean  exgreen.mean  value.mean  \
# 0       3.888889    5.000000     3.333333     -8.333333    8.444445
# 1       3.555556    4.333334     3.333333     -7.666666    7.555555
# 2       3.333333    5.777778     1.777778     -7.555555    7.777778
# 3       3.444444    2.888889     4.888889     -7.777778    7.888889
# 4       3.111111    4.000000     3.333333     -7.333334    7.111111
#
#    saturation.mean  hue-mean
# 0         0.538580 -0.924817
# 1         0.532628 -0.965946
# 2         0.573633 -0.744272
# 3         0.562919 -1.175773
# 4         0.561508 -0.985811

# %%
lbl=LabelEncoder()
image['Class']=lbl.fit_transform(image['Class'])
image.head()
# Out:
#    Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0      0                  188                  133                   9
# 1      0                  105                  139                   9
# 2      0                   34                  137                   9
# 3      0                   39                  111                   9
# 4      0                   16                  128                   9
#
#    short.line.density.5  short.line.density.2  vedge.mean  vegde.sd  \
# 0                   0.0                   0.0    0.333333  0.266667
# 1                   0.0                   0.0    0.277778  0.107407
# 2                   0.0                   0.0    0.500000  0.166667
# 3                   0.0                   0.0    0.722222  0.374074
# 4                   0.0                   0.0    0.500000  0.077778
#
#    hedge.mean  hedge.sd  intensity.mean  rawred.mean  rawblue.mean  \
# 0    0.500000  0.077778        6.666666     8.333334      7.777778
# 1    0.833333  0.522222        6.111111     7.555555      7.222222
# 2    1.111111  0.474074        5.851852     7.777778      6.444445
# 3    0.888889  0.429629        6.037037     7.000000      7.666666
# 4    0.666667  0.311111        5.555555     6.888889      6.666666
#
#    rawgreen.mean  exred.mean  exblue.mean  exgreen.mean  value.mean  \
# 0       3.888889    5.000000     3.333333     -8.333333    8.444445
# 1       3.555556    4.333334     3.333333     -7.666666    7.555555
# 2       3.333333    5.777778     1.777778     -7.555555    7.777778
# 3       3.444444    2.888889     4.888889     -7.777778    7.888889
# 4       3.111111    4.000000     3.333333     -7.333334    7.111111
#
#    saturation.mean  hue-mean
# 0         0.538580 -0.924817
# 1         0.532628 -0.965946
# 2         0.573633 -0.744272
# 3         0.562919 -1.175773
# 4         0.561508 -0.985811

# %%
X=image.drop('Class',axis=1)
y=image['Class']

# %%
svm=SVC(probability=True,random_state=23)
lr=LogisticRegression()
nb=GaussianNB()

# %%
voting=VotingClassifier(estimators=[('SVM',svm),('LR',lr),('NB',nb)],voting='soft')

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
params = {'SVM__gamma':['scale','auto'],
          'SVM__C':np.linspace(0.001,5,5),
          'LR__multi_class':['auto', 'ovr', 'multinomial'],
          'LR__penalty':['l1','l2','elasticnet',None]}
gcv=GridSearchCV(voting,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.637 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.675 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.821 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.748 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.664 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.637 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.675 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.820 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.748 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.664 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.379 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.452 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.580 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.529 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.440 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.632 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.671 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.742 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.665 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.372 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.445 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.580 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.526 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.437 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.632 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.671 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.742 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.665 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.364 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.438 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.579 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.525 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.429 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.632 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.671 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.742 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.665 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.356 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.429 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.581 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.521 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.422 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.632 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.671 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.742 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.665 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# [CV 1/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.638 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.642 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.856 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=3.75025, SVM__gamma=auto;, score=-0.740 total time=   0.1s
# [CV 5/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=3.75025, SVM__gamma=auto;, score=-0.641 total time=   0.1s
# [CV 1/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.357 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.409 total time=   0.1s
# [CV 3/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.607 total time=   0.1s
# [CV 4/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.514 total time=   0.1s
# [CV 5/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.392 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.633 total time=   0.1s
# [CV 2/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.639 total time=   0.1s
# [CV 3/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.850 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 300 fits failed out of a total of 600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 150 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 150 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.70900587 -0.70880108
#  -0.4761669  -0.70540038 -0.47215792 -0.70540038 -0.46704215 -0.70540038
#  -0.46189598 -0.70540038         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.70419506 -0.70398717 -0.46999108 -0.70043343 -0.46629815 -0.70043344
#  -0.46115313 -0.70043344 -0.45580175 -0.70043344         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.71800198 -0.71780147 -0.48736355 -0.71444769
#  -0.48291359 -0.71444768 -0.47663487 -0.71444768 -0.47070695 -0.71444768
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.75912856 -0.75891777
#  -0.51237864 -0.7550682  -0.50651892 -0.75506822 -0.4998692  -0.75506822
#  -0.49369699 -0.75506822         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.70900587 -0.70880108 -0.4761669  -0.70540038 -0.47215792 -0.70540038
#  -0.46704215 -0.70540038 -0.46189598 -0.70540038         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.70419506 -0.70398717 -0.46999108 -0.70043343
#  -0.46629815 -0.70043344 -0.46115313 -0.70043344 -0.45580175 -0.70043344]
#   warnings.warn(
# [CV 4/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.740 total time=   0.1s
# [CV 5/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.641 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=VotingClassifier(estimators=[('SVM',
#                                                      SVC(probability=True,
#                                                          random_state=23)),
#                                                     ('LR',
#                                                      LogisticRegression()),
#                                                     ('NB', GaussianNB())],
#                                         voting='soft'),
#              param_grid={'LR__multi_class': ['auto', 'ovr', 'multinomial'],
#                          'LR__penalty': ['l1', 'l2', 'elasticnet', None],
#                          'SVM__C': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                          'SVM__gamma': ['scale', 'auto']},
#              scoring='neg_log_loss', verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {'LR__multi_class': 'auto', 'LR__penalty': None, 'SVM__C': 5.0, 'SVM__gamma': 'scale'}
# best score : -0.455801754459514

# %% [markdown]
# ## Only SVM

# %%
params={'gamma':['scale','auto'],
          'C':np.linspace(0.001,5,5)}
gcv=GridSearchCV(svm,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .............C=0.001, gamma=scale;, score=-1.962 total time=   0.1s
# [CV 2/5] END .............C=0.001, gamma=scale;, score=-1.962 total time=   0.0s
# [CV 3/5] END .............C=0.001, gamma=scale;, score=-1.962 total time=   0.0s
# [CV 4/5] END .............C=0.001, gamma=scale;, score=-1.962 total time=   0.0s
# [CV 5/5] END .............C=0.001, gamma=scale;, score=-1.947 total time=   0.0s
# [CV 1/5] END ..............C=0.001, gamma=auto;, score=-1.960 total time=   0.0s
# [CV 2/5] END ..............C=0.001, gamma=auto;, score=-1.960 total time=   0.0s
# [CV 3/5] END ..............C=0.001, gamma=auto;, score=-1.960 total time=   0.0s
# [CV 4/5] END ..............C=0.001, gamma=auto;, score=-1.960 total time=   0.0s
# [CV 5/5] END ..............C=0.001, gamma=auto;, score=-1.945 total time=   0.0s
# [CV 1/5] END C=1.2507499999999998, gamma=scale;, score=-0.586 total time=   0.0s
# [CV 2/5] END C=1.2507499999999998, gamma=scale;, score=-0.697 total time=   0.0s
# [CV 3/5] END C=1.2507499999999998, gamma=scale;, score=-0.731 total time=   0.0s
# [CV 4/5] END C=1.2507499999999998, gamma=scale;, score=-0.750 total time=   0.0s
# [CV 5/5] END C=1.2507499999999998, gamma=scale;, score=-0.673 total time=   0.0s
# [CV 1/5] END .C=1.2507499999999998, gamma=auto;, score=-1.963 total time=   0.0s
# [CV 2/5] END .C=1.2507499999999998, gamma=auto;, score=-1.937 total time=   0.1s
# [CV 3/5] END .C=1.2507499999999998, gamma=auto;, score=-1.912 total time=   0.1s
# [CV 4/5] END .C=1.2507499999999998, gamma=auto;, score=-1.951 total time=   0.1s
# [CV 5/5] END .C=1.2507499999999998, gamma=auto;, score=-1.946 total time=   0.1s
# [CV 1/5] END C=2.5004999999999997, gamma=scale;, score=-0.565 total time=   0.0s
# [CV 2/5] END C=2.5004999999999997, gamma=scale;, score=-0.687 total time=   0.0s
# [CV 3/5] END C=2.5004999999999997, gamma=scale;, score=-0.708 total time=   0.0s
# [CV 4/5] END C=2.5004999999999997, gamma=scale;, score=-0.725 total time=   0.0s
# [CV 5/5] END C=2.5004999999999997, gamma=scale;, score=-0.652 total time=   0.0s
# [CV 1/5] END .C=2.5004999999999997, gamma=auto;, score=-1.963 total time=   0.1s
# [CV 2/5] END .C=2.5004999999999997, gamma=auto;, score=-1.937 total time=   0.0s
# [CV 3/5] END .C=2.5004999999999997, gamma=auto;, score=-1.912 total time=   0.1s
# [CV 4/5] END .C=2.5004999999999997, gamma=auto;, score=-1.951 total time=   0.1s
# [CV 5/5] END .C=2.5004999999999997, gamma=auto;, score=-1.946 total time=   0.1s
# [CV 1/5] END ...........C=3.75025, gamma=scale;, score=-0.547 total time=   0.0s
# [CV 2/5] END ...........C=3.75025, gamma=scale;, score=-0.654 total time=   0.0s
# [CV 3/5] END ...........C=3.75025, gamma=scale;, score=-0.693 total time=   0.0s
# [CV 4/5] END ...........C=3.75025, gamma=scale;, score=-0.716 total time=   0.0s
# [CV 5/5] END ...........C=3.75025, gamma=scale;, score=-0.623 total time=   0.0s
# [CV 1/5] END ............C=3.75025, gamma=auto;, score=-1.963 total time=   0.0s
# [CV 2/5] END ............C=3.75025, gamma=auto;, score=-1.937 total time=   0.1s
# [CV 3/5] END ............C=3.75025, gamma=auto;, score=-1.912 total time=   0.0s
# [CV 4/5] END ............C=3.75025, gamma=auto;, score=-1.951 total time=   0.1s
# [CV 5/5] END ............C=3.75025, gamma=auto;, score=-1.946 total time=   0.1s
# [CV 1/5] END ...............C=5.0, gamma=scale;, score=-0.518 total time=   0.0s
# [CV 2/5] END ...............C=5.0, gamma=scale;, score=-0.613 total time=   0.0s
# [CV 3/5] END ...............C=5.0, gamma=scale;, score=-0.687 total time=   0.0s
# [CV 4/5] END ...............C=5.0, gamma=scale;, score=-0.694 total time=   0.0s
# [CV 5/5] END ...............C=5.0, gamma=scale;, score=-0.601 total time=   0.0s
# [CV 1/5] END ................C=5.0, gamma=auto;, score=-1.963 total time=   0.0s
# [CV 2/5] END ................C=5.0, gamma=auto;, score=-1.937 total time=   0.1s
# [CV 3/5] END ................C=5.0, gamma=auto;, score=-1.912 total time=   0.1s
# [CV 4/5] END ................C=5.0, gamma=auto;, score=-1.951 total time=   0.1s
# [CV 5/5] END ................C=5.0, gamma=auto;, score=-1.946 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=SVC(probability=True, random_state=23),
#              param_grid={'C': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                          'gamma': ['scale', 'auto']},
#              scoring='neg_log_loss', verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {'C': 5.0, 'gamma': 'scale'}
# best score : -0.622653795419567

# %% [markdown]
# ## Only LR

# %%
params = {'multi_class':['auto', 'ovr', 'multinomial'],
          'penalty':['l1','l2','elasticnet',None]}
gcv=GridSearchCV(lr,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ........multi_class=auto, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END ........multi_class=auto, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END ........multi_class=auto, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END ........multi_class=auto, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END ........multi_class=auto, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END .....multi_class=auto, penalty=l2;, score=-0.561 total time=   0.0s
# [CV 2/5] END .....multi_class=auto, penalty=l2;, score=-0.528 total time=   0.0s
# [CV 3/5] END .....multi_class=auto, penalty=l2;, score=-1.603 total time=   0.0s
# [CV 4/5] END .....multi_class=auto, penalty=l2;, score=-0.780 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END .....multi_class=auto, penalty=l2;, score=-0.303 total time=   0.0s
# [CV 1/5] END multi_class=auto, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END multi_class=auto, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END multi_class=auto, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END multi_class=auto, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END multi_class=auto, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END ...multi_class=auto, penalty=None;, score=-0.598 total time=   0.0s
# [CV 2/5] END ...multi_class=auto, penalty=None;, score=-0.383 total time=   0.0s
# [CV 3/5] END ...multi_class=auto, penalty=None;, score=-2.344 total time=   0.0s
# [CV 4/5] END ...multi_class=auto, penalty=None;, score=-0.616 total time=   0.0s
# [CV 5/5] END ...multi_class=auto, penalty=None;, score=-0.327 total time=   0.0s
# [CV 1/5] END .........multi_class=ovr, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .........multi_class=ovr, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .........multi_class=ovr, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .........multi_class=ovr, penalty=l1;, score=nan total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END .........multi_class=ovr, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ......multi_class=ovr, penalty=l2;, score=-0.415 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END ......multi_class=ovr, penalty=l2;, score=-0.400 total time=   0.1s
# [CV 3/5] END ......multi_class=ovr, penalty=l2;, score=-1.696 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END ......multi_class=ovr, penalty=l2;, score=-0.425 total time=   0.1s
# [CV 5/5] END ......multi_class=ovr, penalty=l2;, score=-0.436 total time=   0.2s
# [CV 1/5] END .multi_class=ovr, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END .multi_class=ovr, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END .multi_class=ovr, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END .multi_class=ovr, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END .multi_class=ovr, penalty=elasticnet;, score=nan total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END ....multi_class=ovr, penalty=None;, score=-1.599 total time=   0.1s
# [CV 2/5] END ....multi_class=ovr, penalty=None;, score=-0.915 total time=   0.1s
# [CV 3/5] END ....multi_class=ovr, penalty=None;, score=-4.153 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END ....multi_class=ovr, penalty=None;, score=-0.411 total time=   0.1s
# [CV 5/5] END ....multi_class=ovr, penalty=None;, score=-0.842 total time=   0.1s
# [CV 1/5] END .multi_class=multinomial, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .multi_class=multinomial, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .multi_class=multinomial, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .multi_class=multinomial, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .multi_class=multinomial, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END multi_class=multinomial, penalty=l2;, score=-0.561 total time=   0.0s
# [CV 2/5] END multi_class=multinomial, penalty=l2;, score=-0.528 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END multi_class=multinomial, penalty=l2;, score=-1.603 total time=   0.0s
# [CV 4/5] END multi_class=multinomial, penalty=l2;, score=-0.780 total time=   0.0s
# [CV 5/5] END multi_class=multinomial, penalty=l2;, score=-0.303 total time=   0.0s
# [CV 1/5] END multi_class=multinomial, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END multi_class=multinomial, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END multi_class=multinomial, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END multi_class=multinomial, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END multi_class=multinomial, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END multi_class=multinomial, penalty=None;, score=-0.598 total time=   0.0s
# [CV 2/5] END multi_class=multinomial, penalty=None;, score=-0.383 total time=   0.0s
# [CV 3/5] END multi_class=multinomial, penalty=None;, score=-2.344 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [        nan -0.75498498         nan -0.85367178         nan -0.6743863
#          nan -1.58408254         nan -0.75498498         nan -0.85367178]
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END multi_class=multinomial, penalty=None;, score=-0.616 total time=   0.0s
# [CV 5/5] END multi_class=multinomial, penalty=None;, score=-0.327 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'multi_class': ['auto', 'ovr', 'multinomial'],
#                          'penalty': ['l1', 'l2', 'elasticnet', None]},
#              scoring='neg_log_loss', verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {'multi_class': 'ovr', 'penalty': 'l2'}
# best score : -0.674386299672143

# %% [markdown]
# ## Only NB

# %%
params = {}
gcv=GridSearchCV(nb,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END .................................., score=-2.734 total time=   0.0s
# [CV 2/5] END .................................., score=-2.744 total time=   0.0s
# [CV 3/5] END .................................., score=-3.557 total time=   0.0s
# [CV 4/5] END .................................., score=-5.447 total time=   0.0s
# [CV 5/5] END .................................., score=-4.494 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2922: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=GaussianNB(), param_grid={}, scoring='neg_log_loss',
#              verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {}
# best score : -3.795338814659644

# %% [markdown]
# ## weighted

# %%
voting=VotingClassifier(estimators=[('SVM',svm),('LR',lr),('NB',nb)],voting='soft',
                        weights=[0.5,0.4,0.1])

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
params = {'SVM__gamma':['scale','auto'],
          'SVM__C':np.linspace(0.001,5,5),
          'LR__multi_class':['auto', 'ovr', 'multinomial'],
          'LR__penalty':['l1','l2','elasticnet',None]}
gcv=GridSearchCV(voting,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.829 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.857 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.932 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.860 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.788 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.828 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.857 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.932 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.860 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.787 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.403 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.482 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.566 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.529 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.433 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.823 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.850 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.854 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.787 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.393 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.473 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.563 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.523 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.428 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.823 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.850 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.854 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.787 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.383 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.464 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.559 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.522 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.418 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.823 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.850 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.854 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.787 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.372 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.452 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.561 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.516 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.410 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.823 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.850 total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.854 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.787 total time=   0.1s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.830 total time=   0.1s
# [CV 2/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.798 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.964 total time=   0.1s
# [CV 4/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.855 total time=   0.1s
# [CV 5/5] END LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.761 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=3.75025, SVM__gamma=auto;, score=-0.849 total time=   0.1s
# [CV 5/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=3.75025, SVM__gamma=auto;, score=-0.761 total time=   0.1s
# [CV 1/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.372 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.425 total time=   0.1s
# [CV 3/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.582 total time=   0.1s
# [CV 4/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.507 total time=   0.1s
# [CV 5/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=scale;, score=-0.379 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.825 total time=   0.1s
# [CV 2/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.792 total time=   0.1s
# [CV 3/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.954 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.849 total time=   0.1s
# [CV 5/5] END LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.761 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 300 fits failed out of a total of 600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 150 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 150 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.85324346 -0.85293099
#  -0.48253421 -0.84784014 -0.47606528 -0.84784015 -0.46921547 -0.84784015
#  -0.46216685 -0.84784015         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.84142808 -0.84111443 -0.47341003 -0.83620964 -0.46717652 -0.83620967
#  -0.46029119 -0.83620967 -0.45300062 -0.83620967         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.86904777 -0.86872237 -0.50222683 -0.86455242
#  -0.49507076 -0.86455243 -0.48682802 -0.86455243 -0.47858793 -0.86455243
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.92009362 -0.91976047
#  -0.5289763  -0.91467033 -0.52037663 -0.91467036 -0.51170379 -0.91467036
#  -0.50346052 -0.91467036         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.85324346 -0.85293099 -0.48253421 -0.84784014 -0.47606528 -0.84784015
#  -0.46921547 -0.84784015 -0.46216685 -0.84784015         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.84142808 -0.84111443 -0.47341003 -0.83620964
#  -0.46717652 -0.83620967 -0.46029119 -0.83620967 -0.45300062 -0.83620967]
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=VotingClassifier(estimators=[('SVM',
#                                                      SVC(probability=True,
#                                                          random_state=23)),
#                                                     ('LR',
#                                                      LogisticRegression()),
#                                                     ('NB', GaussianNB())],
#                                         voting='soft',
#                                         weights=[0.5, 0.4, 0.1]),
#              param_grid={'LR__multi_class': ['auto', 'ovr', 'multinomial'],
#                          'LR__penalty': ['l1', 'l2', 'elasticnet', None],
#                          'SVM__C': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                          'SVM__gamma': ['scale', 'auto']},
#              scoring='neg_log_loss', verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {'LR__multi_class': 'auto', 'LR__penalty': None, 'SVM__C': 5.0, 'SVM__gamma': 'scale'}
# best score : -0.4530006220909833

# %% [markdown]
# ## Unweighted(using DTC)

# %%
svm=SVC(probability=True,random_state=23)
lr=LogisticRegression()
dtc=DecisionTreeClassifier()

# %%
voting=VotingClassifier(estimators=[('SVM',svm),('LR',lr),('DTC',dtc)],voting='soft')

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
params = {'SVM__gamma':['scale','auto'],
          'SVM__C':np.linspace(0.001,5,5),
          'LR__multi_class':['auto', 'ovr', 'multinomial'],
          'LR__penalty':['l1','l2','elasticnet',None],
          'DTC__max_depth':[2,3,5,10]}
gcv=GridSearchCV(voting,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.850 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.877 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.934 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.874 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.820 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.850 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.927 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.933 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.873 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.820 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.540 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.616 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.675 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.629 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.553 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.849 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.922 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.928 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.871 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.533 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.610 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.670 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.626 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.550 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.849 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.922 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.928 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.871 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.526 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.622 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.666 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.625 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.544 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.849 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.872 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.928 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.871 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.519 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.593 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.666 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.620 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.538 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.880 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.922 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.928 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.871 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.817 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.853 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.847 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.593 total time=   0.1s
# [CV 2/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.574 total time=   0.1s
# [CV 3/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.833 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 1200 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.87089013 -0.88082625
#  -0.60239236 -0.87747761 -0.59788107 -0.87747762 -0.59672175 -0.8674574
#  -0.58706021 -0.88364351         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.86339668 -0.86316922 -0.5952824  -0.86336253 -0.59289282 -0.86339216
#  -0.58540891 -0.86349427 -0.58612971 -0.86349427         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.90304193 -0.90279389 -0.63048287 -0.89622496
#  -0.62569624 -0.90034895 -0.6198498  -0.90061412 -0.61320015 -0.89622497
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.92837315 -0.93841004
#  -0.65238247 -0.92579232 -0.642465   -0.92579233 -0.63632203 -0.93553524
#  -0.63365048 -0.93554074         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.88105407 -0.87066319 -0.60239236 -0.87747761 -0.60184053 -0.87714217
#  -0.59205305 -0.87400138 -0.59117657 -0.86783549         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.86339668 -0.86631651 -0.59747971 -0.86038505
#  -0.59289282 -0.86349427 -0.58487998 -0.86349427 -0.57964271 -0.86038506
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.78529221 -0.78507543
#  -0.53132701 -0.7825743  -0.53116292 -0.77293218 -0.52623443 -0.77293218
#  -0.51676215 -0.77293218         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.77093059 -0.76756684 -0.52667016 -0.76876163 -0.52031664 -0.76876164
#  -0.51523012 -0.76876164 -0.51192286 -0.76565242         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.80066228 -0.80489511 -0.55820394 -0.799147
#  -0.55381865 -0.80353616 -0.5454472  -0.80353616 -0.54184342 -0.80353616
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.83595007 -0.83571294
#  -0.57679322 -0.83371027 -0.57184176 -0.82396187 -0.56202356 -0.82396187
#  -0.55577972 -0.83371028         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.77512827 -0.78507543 -0.53510816 -0.7825743  -0.53116292 -0.77293218
#  -0.52623443 -0.7825743  -0.51676215 -0.7825743          nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.76778324 -0.76756684 -0.52452608 -0.76876163
#  -0.52031664 -0.76565242 -0.51523012 -0.76565242 -0.51192286 -0.76565242
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.65628919 -0.65232057
#  -0.43089606 -0.64653527 -0.42532914 -0.65420923 -0.42199738 -0.66361821
#  -0.41373384 -0.65900895         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.65283399 -0.64528111 -0.41307118 -0.64675747 -0.42692607 -0.6505416
#  -0.41284977 -0.64586492 -0.4138145  -0.65667034         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.66114875 -0.68244101 -0.44507831 -0.66549434
#  -0.4539218  -0.67667788 -0.4420012  -0.66559713 -0.4285582  -0.66475128
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.70729281 -0.70229817
#  -0.46073879 -0.70594546 -0.46810597 -0.7015791  -0.46507799 -0.6905553
#  -0.45085214 -0.71021921         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.65894289 -0.6480161  -0.43334331 -0.66309947 -0.42739766 -0.6738381
#  -0.42372084 -0.64755562 -0.42037375 -0.65010159         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.65461877 -0.64435822 -0.41833523 -0.64364825
#  -0.4119632  -0.64755308 -0.4237536  -0.64284539 -0.41935525 -0.64284539
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.60322798 -0.58940209
#  -0.39584965 -0.62182274 -0.36035708 -0.58785398 -0.39673495 -0.61642227
#  -0.37061759 -0.61163456         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.60632531 -0.59135193 -0.39009921 -0.56455972 -0.36995982 -0.59143208
#  -0.37440204 -0.5888631  -0.36957737 -0.60102091         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.59982158 -0.62412224 -0.40289523 -0.59517256
#  -0.40128162 -0.62985266 -0.40056655 -0.60586649 -0.413093   -0.609547
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.66762263 -0.6338868
#  -0.42376805 -0.67445454 -0.40399298 -0.64588914 -0.42409466 -0.63394779
#  -0.40274222 -0.64310312         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.59442719 -0.60636744 -0.38513694 -0.61897151 -0.3870937  -0.60734814
#  -0.37145076 -0.59763079 -0.3908353  -0.6093862          nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.61371374 -0.56291812 -0.37890942 -0.60220892
#  -0.35902812 -0.60418123 -0.36893197 -0.57650343 -0.37049799 -0.62254461]
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.562 total time=   0.1s
# [CV 5/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.551 total time=   0.1s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=VotingClassifier(estimators=[('SVM',
#                                                      SVC(probability=True,
#                                                          random_state=23)),
#                                                     ('LR',
#                                                      LogisticRegression()),
#                                                     ('DTC',
#                                                      DecisionTreeClassifier())],
#                                         voting='soft'),
#              param_grid={'DTC__max_depth': [2, 3, 5, 10],
#                          'LR__multi_class': ['auto', 'ovr', 'multinomial'],
#                          'LR__penalty': ['l1', 'l2', 'elasticnet', None],
#                          'SVM__C': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                          'SVM__gamma': ['scale', 'auto']},
#              scoring='neg_log_loss', verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {'DTC__max_depth': 10, 'LR__multi_class': 'multinomial', 'LR__penalty': None, 'SVM__C': 2.5004999999999997, 'SVM__gamma': 'scale'}
# best score : -0.3590281206002326

# %% [markdown]
# ## Only DTC

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
params = {'max_depth':[2,3,5,10]}
gcv=GridSearchCV(dtc,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ......................max_depth=2;, score=-1.150 total time=   0.0s
# [CV 2/5] END ......................max_depth=2;, score=-1.150 total time=   0.0s
# [CV 3/5] END ......................max_depth=2;, score=-1.150 total time=   0.0s
# [CV 4/5] END ......................max_depth=2;, score=-1.150 total time=   0.0s
# [CV 5/5] END ......................max_depth=2;, score=-1.138 total time=   0.0s
# [CV 1/5] END ......................max_depth=3;, score=-0.792 total time=   0.0s
# [CV 2/5] END ......................max_depth=3;, score=-0.792 total time=   0.0s
# [CV 3/5] END ......................max_depth=3;, score=-2.509 total time=   0.0s
# [CV 4/5] END ......................max_depth=3;, score=-0.792 total time=   0.0s
# [CV 5/5] END ......................max_depth=3;, score=-0.778 total time=   0.0s
# [CV 1/5] END ......................max_depth=5;, score=-1.243 total time=   0.0s
# [CV 2/5] END ......................max_depth=5;, score=-0.485 total time=   0.0s
# [CV 3/5] END ......................max_depth=5;, score=-4.620 total time=   0.0s
# [CV 4/5] END ......................max_depth=5;, score=-0.280 total time=   0.0s
# [CV 5/5] END ......................max_depth=5;, score=-2.060 total time=   0.0s
# [CV 1/5] END .....................max_depth=10;, score=-3.437 total time=   0.0s
# [CV 2/5] END .....................max_depth=10;, score=-3.433 total time=   0.0s
# [CV 3/5] END .....................max_depth=10;, score=-8.582 total time=   0.0s
# [CV 4/5] END .....................max_depth=10;, score=-2.575 total time=   0.0s
# [CV 5/5] END .....................max_depth=10;, score=-5.275 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 3, 5, 10]}, scoring='neg_log_loss',
#              verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {'max_depth': 3}
# best score : -1.1326199954039187

# %% [markdown]
# ## Weighted with dtc

# %%
voting=VotingClassifier(estimators=[('SVM',svm),('LR',lr),('DTC',dtc)],voting='soft',
                        weights=[0.45,0.35,0.2])

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
params = {'SVM__gamma':['scale','auto'],
          'SVM__C':np.linspace(0.001,5,5),
          'LR__multi_class':['auto', 'ovr', 'multinomial'],
          'LR__penalty':['l1','l2','elasticnet',None],
          'DTC__max_depth':[2,3,5,10]}
gcv=GridSearchCV(voting,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l1, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.904 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.930 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.983 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.921 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=scale;, score=-0.861 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.904 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.929 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.982 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.921 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=0.001, SVM__gamma=auto;, score=-0.862 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.491 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.575 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.634 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.598 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=-0.510 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.902 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.974 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.917 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=-0.860 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.481 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.578 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.629 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.594 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=-0.506 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.902 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.974 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.917 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=-0.860 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.473 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.558 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.624 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.593 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=scale;, score=-0.498 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.902 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.974 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.917 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=3.75025, SVM__gamma=auto;, score=-0.860 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.463 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.546 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.624 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.587 total time=   0.1s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=scale;, score=-0.490 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.902 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.925 total time=   0.1s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.974 total time=   0.1s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.917 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=l2, SVM__C=5.0, SVM__gamma=auto;, score=-0.860 total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 3/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 4/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.0s
# [CV 5/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=elasticnet, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.907 total time=   0.1s
# [CV 2/5] END DTC__max_depth=2, LR__multi_class=auto, LR__penalty=None, SVM__C=0.001, SVM__gamma=scale;, score=-0.901 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...
# [CV 1/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.704 total time=   0.1s
# [CV 2/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.650 total time=   0.1s
# [CV 3/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.829 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.713 total time=   0.1s
# [CV 5/5] END DTC__max_depth=10, LR__multi_class=multinomial, LR__penalty=None, SVM__C=5.0, SVM__gamma=auto;, score=-0.670 total time=   0.1s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 1200 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.91963963 -0.91973786
#  -0.56167367 -0.91553791 -0.55786938 -0.91553792 -0.54911451 -0.91553792
#  -0.54196361 -0.91553792         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.91298494 -0.91267893 -0.5550919  -0.90656024 -0.54773468 -0.90851202
#  -0.5406406  -0.90851202 -0.53371468 -0.91177142         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.94633068 -0.94890161 -0.58629197 -0.9455903
#  -0.57967537 -0.9429037  -0.572165   -0.9429037  -0.56373116 -0.94275752
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.98218506 -0.98215754
#  -0.61005251 -0.97863139 -0.60245    -0.98523075 -0.59462918 -0.98523075
#  -0.58634113 -0.98514871         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.92702613 -0.91973786 -0.56183966 -0.91553791 -0.55523091 -0.91553792
#  -0.54911451 -0.91541533 -0.54423506 -0.92206593         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.91298494 -0.91267893 -0.5550919  -0.908512
#  -0.54773468 -0.90656026 -0.54228199 -0.90844409 -0.53371468 -0.90802295
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.85840918 -0.85811271
#  -0.52223021 -0.85471747 -0.51440185 -0.85471748 -0.51017835 -0.86124549
#  -0.50096181 -0.86124549         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.85134897 -0.85105202 -0.51367516 -0.84576815 -0.50789877 -0.84771992
#  -0.50011571 -0.84771992 -0.49295357 -0.84771992         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.88617019 -0.88584694 -0.54549833 -0.88063057
#  -0.53931195 -0.88063057 -0.53203448 -0.88063057 -0.52224038 -0.88346336
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.92185654 -0.91446491
#  -0.56564109 -0.9118069  -0.55646753 -0.91180692 -0.54886257 -0.91840625
#  -0.54078329 -0.91840625         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.85840918 -0.86509464 -0.52017605 -0.85471747 -0.51440185 -0.86124549
#  -0.50797464 -0.85471748 -0.50323327 -0.86124549         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.84936397 -0.85105202 -0.51247466 -0.84576815
#  -0.50789877 -0.84771992 -0.50011571 -0.84576816 -0.49422429 -0.84576816
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.78320429 -0.77790733
#  -0.46012243 -0.77548947 -0.45249489 -0.77290761 -0.4473257  -0.77554004
#  -0.43960302 -0.77345849         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.76110898 -0.7698844  -0.44916835 -0.76635709 -0.44709242 -0.77114757
#  -0.43264825 -0.76739799 -0.43473629 -0.76181398         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.80055135 -0.78837376 -0.47501653 -0.79553821
#  -0.47574355 -0.79914125 -0.46046094 -0.8059833  -0.4630366  -0.78815335
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.84478469 -0.83769222
#  -0.50059017 -0.81662323 -0.48946609 -0.83078863 -0.48459822 -0.83417693
#  -0.4737012  -0.83385936         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.77227184 -0.78094243 -0.45086714 -0.76708993 -0.45521197 -0.77446257
#  -0.44302671 -0.77446257 -0.43530814 -0.77638464         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.77712331 -0.76996709 -0.45165859 -0.77309928
#  -0.44712667 -0.76291494 -0.43761891 -0.76745809 -0.43347088 -0.75907152
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.72759862 -0.7453867
#  -0.42438332 -0.732365   -0.42020379 -0.74589615 -0.41502477 -0.72945493
#  -0.41185296 -0.72599533         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.7055221  -0.73469356 -0.43111656 -0.73207669 -0.40874495 -0.71608799
#  -0.40746268 -0.72048159 -0.40741451 -0.71699957         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.76142682 -0.74903426 -0.42750768 -0.75812433
#  -0.43932172 -0.76102868 -0.43039909 -0.75484424 -0.41701866 -0.75058816
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan -0.79804197 -0.77868272
#  -0.47738443 -0.78395011 -0.46833058 -0.77095522 -0.45693985 -0.77033738
#  -0.45134424 -0.78320462         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.72326216 -0.74413517 -0.42736199 -0.72426218 -0.41971407 -0.73227516
#  -0.41532592 -0.73712797 -0.40800912 -0.72827183         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.7331321  -0.7202186  -0.42385883 -0.74132377
#  -0.41384637 -0.71126376 -0.40968246 -0.72244256 -0.39505066 -0.71325403]
#   warnings.warn(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=VotingClassifier(estimators=[('SVM',
#                                                      SVC(probability=True,
#                                                          random_state=23)),
#                                                     ('LR',
#                                                      LogisticRegression()),
#                                                     ('DTC',
#                                                      DecisionTreeClassifier())],
#                                         voting='soft',
#                                         weights=[0.45, 0.35, 0.2]),
#              param_grid={'DTC__max_depth': [2, 3, 5, 10],
#                          'LR__multi_class': ['auto', 'ovr', 'multinomial'],
#                          'LR__penalty': ['l1', 'l2', 'elasticnet', None],
#                          'SVM__C': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                          'SVM__gamma': ['scale', 'auto']},
#              scoring='neg_log_loss', verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
# Out:
# best parameter : {'DTC__max_depth': 10, 'LR__multi_class': 'multinomial', 'LR__penalty': None, 'SVM__C': 5.0, 'SVM__gamma': 'scale'}
# best score : -0.395050660477936
