# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler,MinMaxScaler
from sklearn.ensemble import VotingRegressor
from sklearn.svm import SVC
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split,KFold,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import accuracy_score,log_loss
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline

# %%
concrete=pd.read_csv("Concrete_Data.csv")
concrete.head()
# Out:
#    Cement  Blast  Fly  Water  Superplasticizer  Coarse   Fine  Age  Strength
# 0   540.0    0.0  0.0  162.0               2.5  1040.0  676.0   28     79.99
# 1   540.0    0.0  0.0  162.0               2.5  1055.0  676.0   28     61.89
# 2   332.5  142.5  0.0  228.0               0.0   932.0  594.0  270     40.27
# 3   332.5  142.5  0.0  228.0               0.0   932.0  594.0  365     41.05
# 4   198.6  132.4  0.0  192.0               0.0   978.4  825.5  360     44.30

# %%
X=concrete.drop("Strength",axis=1)
y=concrete['Strength']

# %%
kfold=KFold(n_splits=5,shuffle=True,random_state=23)

# %%
##ElasticNet
elastic=ElasticNet()
params={'alpha':np.linspace(0.001,5,5),'l1_ratio':np.linspace(0,1,5)}
gcv=GridSearchCV(elastic,param_grid=params,cv=kfold,scoring='r2',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .........alpha=0.001, l1_ratio=0.0;, score=0.668 total time=   0.1s
# [CV 2/5] END .........alpha=0.001, l1_ratio=0.0;, score=0.555 total time=   0.0s
# [CV 3/5] END .........alpha=0.001, l1_ratio=0.0;, score=0.657 total time=   0.0s
# [CV 4/5] END .........alpha=0.001, l1_ratio=0.0;, score=0.574 total time=   0.0s
# [CV 5/5] END .........alpha=0.001, l1_ratio=0.0;, score=0.548 total time=   0.0s
# [CV 1/5] END ........alpha=0.001, l1_ratio=0.25;, score=0.668 total time=   0.0s
# [CV 2/5] END ........alpha=0.001, l1_ratio=0.25;, score=0.555 total time=   0.0s
# [CV 3/5] END ........alpha=0.001, l1_ratio=0.25;, score=0.657 total time=   0.0s
# [CV 4/5] END ........alpha=0.001, l1_ratio=0.25;, score=0.574 total time=   0.0s
# [CV 5/5] END ........alpha=0.001, l1_ratio=0.25;, score=0.548 total time=   0.0s
# [CV 1/5] END .........alpha=0.001, l1_ratio=0.5;, score=0.668 total time=   0.0s
# [CV 2/5] END .........alpha=0.001, l1_ratio=0.5;, score=0.555 total time=   0.0s
# [CV 3/5] END .........alpha=0.001, l1_ratio=0.5;, score=0.657 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.522e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.313e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.482e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.332e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.374e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 4/5] END .........alpha=0.001, l1_ratio=0.5;, score=0.574 total time=   0.0s
# [CV 5/5] END .........alpha=0.001, l1_ratio=0.5;, score=0.548 total time=   0.0s
# [CV 1/5] END ........alpha=0.001, l1_ratio=0.75;, score=0.668 total time=   0.0s
# [CV 2/5] END ........alpha=0.001, l1_ratio=0.75;, score=0.555 total time=   0.0s
# [CV 3/5] END ........alpha=0.001, l1_ratio=0.75;, score=0.657 total time=   0.0s
# [CV 4/5] END ........alpha=0.001, l1_ratio=0.75;, score=0.574 total time=   0.0s
# [CV 5/5] END ........alpha=0.001, l1_ratio=0.75;, score=0.548 total time=   0.0s
# [CV 1/5] END .........alpha=0.001, l1_ratio=1.0;, score=0.668 total time=   0.0s
# [CV 2/5] END .........alpha=0.001, l1_ratio=1.0;, score=0.555 total time=   0.0s
# [CV 3/5] END .........alpha=0.001, l1_ratio=1.0;, score=0.657 total time=   0.0s
# [CV 4/5] END .........alpha=0.001, l1_ratio=1.0;, score=0.574 total time=   0.0s
# [CV 5/5] END .........alpha=0.001, l1_ratio=1.0;, score=0.548 total time=   0.0s
# [CV 1/5] END alpha=1.2507499999999998, l1_ratio=0.0;, score=0.668 total time=   0.0s
# [CV 2/5] END alpha=1.2507499999999998, l1_ratio=0.0;, score=0.555 total time=   0.0s
# [CV 3/5] END alpha=1.2507499999999998, l1_ratio=0.0;, score=0.656 total time=   0.0s
# [CV 4/5] END alpha=1.2507499999999998, l1_ratio=0.0;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=1.2507499999999998, l1_ratio=0.0;, score=0.549 total time=   0.0s
# [CV 1/5] END alpha=1.2507499999999998, l1_ratio=0.25;, score=0.667 total time=   0.0s
# [CV 2/5] END alpha=1.2507499999999998, l1_ratio=0.25;, score=0.556 total time=   0.0s
# [CV 3/5] END alpha=1.2507499999999998, l1_ratio=0.25;, score=0.656 total time=   0.0s
# [CV 4/5] END alpha=1.2507499999999998, l1_ratio=0.25;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=1.2507499999999998, l1_ratio=0.25;, score=0.549 total time=   0.0s
# [CV 1/5] END alpha=1.2507499999999998, l1_ratio=0.5;, score=0.667 total time=   0.0s
# [CV 2/5] END alpha=1.2507499999999998, l1_ratio=0.5;, score=0.556 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.528e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.322e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.488e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.339e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.383e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 3/5] END alpha=1.2507499999999998, l1_ratio=0.5;, score=0.655 total time=   0.0s
# [CV 4/5] END alpha=1.2507499999999998, l1_ratio=0.5;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=1.2507499999999998, l1_ratio=0.5;, score=0.550 total time=   0.0s
# [CV 1/5] END alpha=1.2507499999999998, l1_ratio=0.75;, score=0.666 total time=   0.0s
# [CV 2/5] END alpha=1.2507499999999998, l1_ratio=0.75;, score=0.557 total time=   0.0s
# [CV 3/5] END alpha=1.2507499999999998, l1_ratio=0.75;, score=0.654 total time=   0.0s
# [CV 4/5] END alpha=1.2507499999999998, l1_ratio=0.75;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=1.2507499999999998, l1_ratio=0.75;, score=0.550 total time=   0.0s
# [CV 1/5] END alpha=1.2507499999999998, l1_ratio=1.0;, score=0.665 total time=   0.0s
# [CV 2/5] END alpha=1.2507499999999998, l1_ratio=1.0;, score=0.557 total time=   0.0s
# [CV 3/5] END alpha=1.2507499999999998, l1_ratio=1.0;, score=0.653 total time=   0.0s
# [CV 4/5] END alpha=1.2507499999999998, l1_ratio=1.0;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=1.2507499999999998, l1_ratio=1.0;, score=0.551 total time=   0.0s
# [CV 1/5] END alpha=2.5004999999999997, l1_ratio=0.0;, score=0.668 total time=   0.0s
# [CV 2/5] END alpha=2.5004999999999997, l1_ratio=0.0;, score=0.556 total time=   0.0s
# [CV 3/5] END alpha=2.5004999999999997, l1_ratio=0.0;, score=0.656 total time=   0.0s
# [CV 4/5] END alpha=2.5004999999999997, l1_ratio=0.0;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=2.5004999999999997, l1_ratio=0.0;, score=0.550 total time=   0.0s
# [CV 1/5] END alpha=2.5004999999999997, l1_ratio=0.25;, score=0.667 total time=   0.0s
# [CV 2/5] END alpha=2.5004999999999997, l1_ratio=0.25;, score=0.557 total time=   0.0s
# [CV 3/5] END alpha=2.5004999999999997, l1_ratio=0.25;, score=0.654 total time=   0.0s
# [CV 4/5] END alpha=2.5004999999999997, l1_ratio=0.25;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=2.5004999999999997, l1_ratio=0.25;, score=0.551 total time=   0.0s
# [CV 1/5] END alpha=2.5004999999999997, l1_ratio=0.5;, score=0.665 total time=   0.0s
# [CV 2/5] END alpha=2.5004999999999997, l1_ratio=0.5;, score=0.557 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.535e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.331e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.494e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.346e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.392e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 3/5] END alpha=2.5004999999999997, l1_ratio=0.5;, score=0.653 total time=   0.0s
# [CV 4/5] END alpha=2.5004999999999997, l1_ratio=0.5;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=2.5004999999999997, l1_ratio=0.5;, score=0.551 total time=   0.0s
# [CV 1/5] END alpha=2.5004999999999997, l1_ratio=0.75;, score=0.664 total time=   0.0s
# [CV 2/5] END alpha=2.5004999999999997, l1_ratio=0.75;, score=0.558 total time=   0.0s
# [CV 3/5] END alpha=2.5004999999999997, l1_ratio=0.75;, score=0.651 total time=   0.0s
# [CV 4/5] END alpha=2.5004999999999997, l1_ratio=0.75;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=2.5004999999999997, l1_ratio=0.75;, score=0.552 total time=   0.0s
# [CV 1/5] END alpha=2.5004999999999997, l1_ratio=1.0;, score=0.663 total time=   0.0s
# [CV 2/5] END alpha=2.5004999999999997, l1_ratio=1.0;, score=0.559 total time=   0.0s
# [CV 3/5] END alpha=2.5004999999999997, l1_ratio=1.0;, score=0.649 total time=   0.0s
# [CV 4/5] END alpha=2.5004999999999997, l1_ratio=1.0;, score=0.574 total time=   0.0s
# [CV 5/5] END alpha=2.5004999999999997, l1_ratio=1.0;, score=0.552 total time=   0.0s
# [CV 1/5] END .......alpha=3.75025, l1_ratio=0.0;, score=0.667 total time=   0.0s
# [CV 2/5] END .......alpha=3.75025, l1_ratio=0.0;, score=0.556 total time=   0.0s
# [CV 3/5] END .......alpha=3.75025, l1_ratio=0.0;, score=0.655 total time=   0.0s
# [CV 4/5] END .......alpha=3.75025, l1_ratio=0.0;, score=0.574 total time=   0.0s
# [CV 5/5] END .......alpha=3.75025, l1_ratio=0.0;, score=0.551 total time=   0.0s
# [CV 1/5] END ......alpha=3.75025, l1_ratio=0.25;, score=0.666 total time=   0.0s
# [CV 2/5] END ......alpha=3.75025, l1_ratio=0.25;, score=0.557 total time=   0.0s
# [CV 3/5] END ......alpha=3.75025, l1_ratio=0.25;, score=0.653 total time=   0.0s
# [CV 4/5] END ......alpha=3.75025, l1_ratio=0.25;, score=0.574 total time=   0.0s
# [CV 5/5] END ......alpha=3.75025, l1_ratio=0.25;, score=0.551 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.338e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 1/5] END .......alpha=3.75025, l1_ratio=0.5;, score=0.664 total time=   0.0s
# [CV 2/5] END .......alpha=3.75025, l1_ratio=0.5;, score=0.558 total time=   0.0s
# [CV 3/5] END .......alpha=3.75025, l1_ratio=0.5;, score=0.651 total time=   0.0s
# [CV 4/5] END .......alpha=3.75025, l1_ratio=0.5;, score=0.574 total time=   0.0s
# [CV 5/5] END .......alpha=3.75025, l1_ratio=0.5;, score=0.552 total time=   0.0s
# [CV 1/5] END ......alpha=3.75025, l1_ratio=0.75;, score=0.662 total time=   0.0s
# [CV 2/5] END ......alpha=3.75025, l1_ratio=0.75;, score=0.559 total time=   0.0s
# [CV 3/5] END ......alpha=3.75025, l1_ratio=0.75;, score=0.648 total time=   0.0s
# [CV 4/5] END ......alpha=3.75025, l1_ratio=0.75;, score=0.574 total time=   0.0s
# [CV 5/5] END ......alpha=3.75025, l1_ratio=0.75;, score=0.553 total time=   0.0s
# [CV 1/5] END .......alpha=3.75025, l1_ratio=1.0;, score=0.661 total time=   0.0s
# [CV 2/5] END .......alpha=3.75025, l1_ratio=1.0;, score=0.560 total time=   0.0s
# [CV 3/5] END .......alpha=3.75025, l1_ratio=1.0;, score=0.645 total time=   0.0s
# [CV 4/5] END .......alpha=3.75025, l1_ratio=1.0;, score=0.573 total time=   0.0s
# [CV 5/5] END .......alpha=3.75025, l1_ratio=1.0;, score=0.553 total time=   0.0s
# [CV 1/5] END ...........alpha=5.0, l1_ratio=0.0;, score=0.667 total time=   0.0s
# [CV 2/5] END ...........alpha=5.0, l1_ratio=0.0;, score=0.557 total time=   0.0s
# [CV 3/5] END ...........alpha=5.0, l1_ratio=0.0;, score=0.655 total time=   0.0s
# [CV 4/5] END ...........alpha=5.0, l1_ratio=0.0;, score=0.574 total time=   0.0s
# [CV 5/5] END ...........alpha=5.0, l1_ratio=0.0;, score=0.551 total time=   0.0s
# [CV 1/5] END ..........alpha=5.0, l1_ratio=0.25;, score=0.665 total time=   0.0s
# [CV 2/5] END ..........alpha=5.0, l1_ratio=0.25;, score=0.558 total time=   0.0s
# [CV 3/5] END ..........alpha=5.0, l1_ratio=0.25;, score=0.652 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.547e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.346e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.504e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.359e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.408e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 4/5] END ..........alpha=5.0, l1_ratio=0.25;, score=0.574 total time=   0.0s
# [CV 5/5] END ..........alpha=5.0, l1_ratio=0.25;, score=0.552 total time=   0.0s
# [CV 1/5] END ...........alpha=5.0, l1_ratio=0.5;, score=0.663 total time=   0.0s
# [CV 2/5] END ...........alpha=5.0, l1_ratio=0.5;, score=0.559 total time=   0.0s
# [CV 3/5] END ...........alpha=5.0, l1_ratio=0.5;, score=0.649 total time=   0.0s
# [CV 4/5] END ...........alpha=5.0, l1_ratio=0.5;, score=0.574 total time=   0.0s
# [CV 5/5] END ...........alpha=5.0, l1_ratio=0.5;, score=0.553 total time=   0.0s
# [CV 1/5] END ..........alpha=5.0, l1_ratio=0.75;, score=0.661 total time=   0.0s
# [CV 2/5] END ..........alpha=5.0, l1_ratio=0.75;, score=0.560 total time=   0.0s
# [CV 3/5] END ..........alpha=5.0, l1_ratio=0.75;, score=0.645 total time=   0.0s
# [CV 4/5] END ..........alpha=5.0, l1_ratio=0.75;, score=0.573 total time=   0.0s
# [CV 5/5] END ..........alpha=5.0, l1_ratio=0.75;, score=0.554 total time=   0.0s
# [CV 1/5] END ...........alpha=5.0, l1_ratio=1.0;, score=0.661 total time=   0.0s
# [CV 2/5] END ...........alpha=5.0, l1_ratio=1.0;, score=0.560 total time=   0.0s
# [CV 3/5] END ...........alpha=5.0, l1_ratio=1.0;, score=0.644 total time=   0.0s
# [CV 4/5] END ...........alpha=5.0, l1_ratio=1.0;, score=0.573 total time=   0.0s
# [CV 5/5] END ...........alpha=5.0, l1_ratio=1.0;, score=0.555 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.555e+04, tolerance: 2.872e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=ElasticNet(),
#              param_grid={'alpha': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                          'l1_ratio': array([0.  , 0.25, 0.5 , 0.75, 1.  ])},
#              scoring='r2', verbose=3)

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
elastic_score=gcv.best_score_
# Out:
# best parameter : {'alpha': 5.0, 'l1_ratio': 0.0}
# best score : 0.6006431793947039

# %%
##KNR
scaler=StandardScaler()
knr=KNeighborsRegressor()
pipe=Pipeline([('SCL',scaler),('KNR',knr)])
params={'KNR__n_neighbors':[1,2,3,4,5],'SCL':[StandardScaler(),MinMaxScaler()]}
gcv=GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='r2')
gcv.fit(X,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', StandardScaler()),
#                                        ('KNR', KNeighborsRegressor())]),
#              param_grid={'KNR__n_neighbors': [1, 2, 3, 4, 5],
#                          'SCL': [StandardScaler(), MinMaxScaler()]},
#              scoring='r2')

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
knr_score=gcv.best_score_
# Out:
# best parameter : {'KNR__n_neighbors': 4, 'SCL': StandardScaler()}
# best score : 0.715311710031387

# %%
##DTR
dtr=DecisionTreeRegressor()
params={'max_depth':[None,3,5],'min_samples_split':[2,5,10],'min_samples_leaf':[1,5,10]}
gcv=GridSearchCV(dtr,param_grid=params,cv=kfold,scoring='r2')
gcv.fit(X,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [None, 3, 5],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='r2')

# %%
print("best parameter :",gcv.best_params_)
print("best score :",gcv.best_score_)
dtr_score=gcv.best_score_
# Out:
# best parameter : {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# best score : 0.8473530592189679

# %% [markdown]
# ## Unweighted Voting

# %%
voting=VotingRegressor(estimators=[('Elastic',elastic),('KNR',pipe),('DTR',dtr)])

# %%
params={'Elastic__alpha':np.linspace(0.001,5,5),'Elastic__l1_ratio':np.linspace(0,1,5),
        'KNR__SCL':[StandardScaler(),MinMaxScaler()],'KNR__KNR__n_neighbors':[1,2,3,4],
        'DTR__max_depth':[None,3,5],'DTR__min_samples_leaf':[1,5,10],
        'DTR__min_samples_split':[2,5,10]}
rgcv=RandomizedSearchCV(voting,param_distributions=params,n_iter=300,cv=kfold,
                       scoring='r2',verbose=3,random_state=23)
rgcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.839 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.822 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.842 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.829 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.814 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.796 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.833 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.806 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.779 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.796 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.754 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.816 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.804 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.760 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.840 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.823 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.861 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.820 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.792 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.795 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.755 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.814 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.803 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.760 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.842 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.823 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.868 total time=   0.1s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.832 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.794 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.773 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.747 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.798 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.338e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.769 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.747 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.830 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.818 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.851 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.806 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.782 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.828 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.814 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.853 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.802 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.782 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.849 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.806 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.861 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.841 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.802 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.772 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.746 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.804 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.775 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.748 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.834 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.821 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.839 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.826 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.772 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.847 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.821 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.865 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.835 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.787 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.799 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.807 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.825 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.787 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.766 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.796 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.754 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.816 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.804 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.760 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.801 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.770 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.814 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.804 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.763 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.828 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.806 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.839 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.823 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.767 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.847 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.827 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.852 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.841 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.777 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.781 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.547e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.346e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.504e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.359e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.408e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.730 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.802 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.788 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.760 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.758 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.742 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.789 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.757 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.743 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.778 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.745 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.800 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.789 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.763 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.824 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.788 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.840 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.821 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.775 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.794 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.796 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.822 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.777 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.761 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.759 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.742 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.789 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.758 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.743 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.773 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.746 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.528e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.322e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.488e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.339e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.383e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.804 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.775 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.748 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.820 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.823 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.851 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.801 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.786 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.778 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.744 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.802 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.790 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.763 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.801 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.770 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.814 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.803 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.763 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.803 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.798 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.830 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.791 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.755 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.828 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.818 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.802 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.781 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.772 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.746 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.803 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.775 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.748 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.859 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.827 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.873 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.849 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.338e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.793 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.848 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.820 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.865 total time=   0.1s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.836 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.788 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.821 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.803 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.839 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.820 total time=   0.0s
# ...
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.338e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.840 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.820 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.776 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.759 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.742 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.789 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.758 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.743 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.782 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.729 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.803 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.788 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.760 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.761 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.756 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.792 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.763 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.749 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.799 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.808 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.824 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.787 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.766 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.821 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.825 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.852 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.802 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.786 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.822 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.822 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.853 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.802 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.785 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.847 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.807 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.862 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.842 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.801 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.828 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.806 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.839 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.823 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.767 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.846 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.819 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.861 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.829 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.798 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.835 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.831 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.866 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.828 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.798 total time=   0.0s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=23, shuffle=True),
#                    estimator=VotingRegressor(estimators=[('Elastic',
#                                                           ElasticNet()),
#                                                          ('KNR',
#                                                           Pipeline(steps=[('SCL',
#                                                                            StandardScaler()),
#                                                                           ('KNR',
#                                                                            KNeighborsRegressor())])),
#                                                          ('DTR',
#                                                           DecisionTreeRegressor())]),
#                    n_iter=300,
#                    param_distributions={'DTR__max_depth': [None, 3, 5],
#                                         'DTR__min_samples_leaf': [1, 5, 10],
#                                         'DTR__min_samples_split': [2, 5, 10],
#                                         'Elastic__alpha': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                                         'Elastic__l1_ratio': array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#                                         'KNR__KNR__n_neighbors': [1, 2, 3, 4],
#                                         'KNR__SCL': [StandardScaler(),
#                                                      MinMaxScaler()]},
#                    random_state=23, scoring='r2', verbose=3)

# %%
print("best parameter :",rgcv.best_params_)
print("best score :",rgcv.best_score_)
unweighted_score=rgcv.best_score_
# Out:
# best parameter : {'KNR__SCL': StandardScaler(), 'KNR__KNR__n_neighbors': 1, 'Elastic__l1_ratio': 1.0, 'Elastic__alpha': 1.2507499999999998, 'DTR__min_samples_split': 2, 'DTR__min_samples_leaf': 1, 'DTR__max_depth': None}
# best score : 0.8490555662482346

# %%
print("Unweighted Score= ",unweighted_score)
print("ElasticNet Score= ",elastic_score)
print("Scaling+KNR Score= ",knr_score)
print("DTR Score= ",dtr_score)
# Out:
# Unweighted Score=  0.8490555662482346
# ElasticNet Score=  0.6006431793947039
# Scaling+KNR Score=  0.715311710031387
# DTR Score=  0.8473530592189679

# %% [markdown]
# ## Weighted Voting

# %%
voting=VotingRegressor(estimators=[('Elastic',elastic),('KNR',pipe),('DTR',dtr)],
                       weights=[0.6006431793947039,0.715311710031387,0.8473530592189679])

# %%
params={'Elastic__alpha':np.linspace(0.001,5,5),'Elastic__l1_ratio':np.linspace(0,1,5),
        'KNR__SCL':[StandardScaler(),MinMaxScaler()],'KNR__KNR__n_neighbors':[1,2,3,4],
        'DTR__max_depth':[None,3,5],'DTR__min_samples_leaf':[1,5,10],
        'DTR__min_samples_split':[2,5,10]}
rgcv=RandomizedSearchCV(voting,param_distributions=params,n_iter=300,cv=kfold,
                       scoring='r2',verbose=3,random_state=23)
rgcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.843 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.833 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.847 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.834 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.789 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.818 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.809 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.842 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.813 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.787 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.793 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.757 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.818 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.764 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.853 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.844 total time=   0.1s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.875 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.839 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.806 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.792 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.758 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.816 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.804 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.764 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.853 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.841 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.882 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.844 total time=   0.1s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.807 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.770 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.752 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.801 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.773 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.338e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.752 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.841 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.836 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.868 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.821 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.795 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.836 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.831 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.866 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.816 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.796 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.858 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.826 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.877 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.853 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.814 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.770 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.750 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.806 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.779 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.753 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.837 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.832 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.844 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.831 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.836 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.876 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.845 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.799 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.804 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.820 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.832 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.796 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.776 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.793 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.758 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.818 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.764 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.798 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.772 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.816 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.803 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.766 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.832 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.818 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.845 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.829 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.775 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.852 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.547e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.346e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.504e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.359e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.408e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.840 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.860 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.851 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=5.0, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.788 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.779 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.736 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.806 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.791 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.764 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.747 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.792 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.761 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.748 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.775 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.749 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.804 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.792 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.766 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.829 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.804 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.851 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.832 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=10, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.786 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.799 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.809 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.830 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.786 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.771 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.757 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.747 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.792 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.762 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.528e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.322e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.488e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.339e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.383e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.748 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.770 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.750 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.807 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.779 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.753 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.829 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.838 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.865 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.815 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.800 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.775 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.748 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.792 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=1.2507499999999998, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.766 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.798 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.772 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.815 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.803 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=1, KNR__SCL=StandardScaler();, score=0.766 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.807 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.811 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.837 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.798 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.765 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.835 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.835 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.867 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.816 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=3, KNR__SCL=MinMaxScaler();, score=0.795 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.769 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.750 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.806 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.779 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=3, KNR__SCL=StandardScaler();, score=0.753 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.338e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.869 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.844 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.887 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.864 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.806 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.835 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.875 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.845 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.800 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.826 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.818 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.849 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.831 total time=   0.0s
# ...
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.832 total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+04, tolerance: 2.258e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.338e+04, tolerance: 2.326e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+04, tolerance: 2.254e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e+04, tolerance: 2.301e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.400e+04, tolerance: 2.344e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=3.75025, Elastic__l1_ratio=0.0, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.786 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.757 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.747 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.792 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.761 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=MinMaxScaler();, score=0.748 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.779 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.735 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.807 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.791 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.764 total time=   0.0s
# [CV 1/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.758 total time=   0.0s
# [CV 2/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.760 total time=   0.0s
# [CV 3/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.795 total time=   0.0s
# [CV 4/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.767 total time=   0.0s
# [CV 5/5] END DTR__max_depth=3, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=1.0, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.753 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.804 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.820 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.831 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.796 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.776 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.829 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.837 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.866 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.815 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=2, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.799 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.830 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.838 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.866 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.816 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=5, DTR__min_samples_split=10, Elastic__alpha=2.5004999999999997, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.799 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.858 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.826 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.877 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.856 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=5, Elastic__alpha=0.001, Elastic__l1_ratio=0.75, KNR__KNR__n_neighbors=2, KNR__SCL=MinMaxScaler();, score=0.814 total time=   0.0s
# [CV 1/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.832 total time=   0.0s
# [CV 2/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.818 total time=   0.0s
# [CV 3/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.845 total time=   0.0s
# [CV 4/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.829 total time=   0.0s
# [CV 5/5] END DTR__max_depth=5, DTR__min_samples_leaf=10, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=1, KNR__SCL=MinMaxScaler();, score=0.776 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.855 total time=   0.1s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.835 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.873 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.842 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=10, Elastic__alpha=5.0, Elastic__l1_ratio=0.5, KNR__KNR__n_neighbors=2, KNR__SCL=StandardScaler();, score=0.808 total time=   0.0s
# [CV 1/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.846 total time=   0.0s
# [CV 2/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.850 total time=   0.0s
# [CV 3/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.882 total time=   0.0s
# [CV 4/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.846 total time=   0.0s
# [CV 5/5] END DTR__max_depth=None, DTR__min_samples_leaf=1, DTR__min_samples_split=2, Elastic__alpha=5.0, Elastic__l1_ratio=0.25, KNR__KNR__n_neighbors=4, KNR__SCL=StandardScaler();, score=0.808 total time=   0.0s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=23, shuffle=True),
#                    estimator=VotingRegressor(estimators=[('Elastic',
#                                                           ElasticNet()),
#                                                          ('KNR',
#                                                           Pipeline(steps=[('SCL',
#                                                                            StandardScaler()),
#                                                                           ('KNR',
#                                                                            KNeighborsRegressor())])),
#                                                          ('DTR',
#                                                           DecisionTreeRegressor())],
#                                              weights=[0.6006431793947039,
#                                                       0.715311710031387,
#                                                       0.8473530592189679]),
#                    n_iter=300,
#                    param_distributions={'DTR__max_depth': [None, 3, 5],
#                                         'DTR__min_samples_leaf': [1, 5, 10],
#                                         'DTR__min_samples_split': [2, 5, 10],
#                                         'Elastic__alpha': array([1.00000e-03, 1.25075e+00, 2.50050e+00, 3.75025e+00, 5.00000e+00]),
#                                         'Elastic__l1_ratio': array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#                                         'KNR__KNR__n_neighbors': [1, 2, 3, 4],
#                                         'KNR__SCL': [StandardScaler(),
#                                                      MinMaxScaler()]},
#                    random_state=23, scoring='r2', verbose=3)

# %%
print("best parameter :",rgcv.best_params_)
print("best score :",rgcv.best_score_)
weighted_score=rgcv.best_score_
# Out:
# best parameter : {'KNR__SCL': StandardScaler(), 'KNR__KNR__n_neighbors': 1, 'Elastic__l1_ratio': 1.0, 'Elastic__alpha': 1.2507499999999998, 'DTR__min_samples_split': 2, 'DTR__min_samples_leaf': 1, 'DTR__max_depth': None}
# best score : 0.8634165533167802

# %%
print("Weighted Score= ",weighted_score)
print("Unweighted Score= ",unweighted_score)
print("ElasticNet Score= ",elastic_score)
print("Scaling+KNR Score= ",knr_score)
print("DTR Score= ",dtr_score)
# Out:
# Weighted Score=  0.8634165533167802
# Unweighted Score=  0.8490555662482346
# ElasticNet Score=  0.6006431793947039
# Scaling+KNR Score=  0.715311710031387
# DTR Score=  0.8473530592189679
