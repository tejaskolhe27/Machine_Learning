# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV,StratifiedKFold
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.compose import make_column_selector,make_column_transformer

# %%
comp_bankruptcy=pd.read_csv("data.csv")
comp_bankruptcy.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                   1
# 1                                           0.570175                   1
# 2                                           0.563706                   1
# 3                                           0.564663                   1
# 4                                           0.575617                   1
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %%
X=comp_bankruptcy.drop('Bankrupt?',axis=1)
y=comp_bankruptcy['Bankrupt?']

# %%
prcomp=PCA()
scaler=MinMaxScaler()
svm=SVC(kernel='linear')
pipe_pca=Pipeline([('SCL',scaler),('PCA',prcomp),('SVM',svm)])

# %%
kfold=StratifiedKFold(n_splits=5,random_state=23,shuffle=True)
params={'PCA__n_components':[0.75,0.8,0.85,0.9],'SVM__C':np.linspace(0.001,3,5)}

# %%
gcv=GridSearchCV(pipe_pca,param_grid=params,cv=kfold,verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END PCA__n_components=0.75, SVM__C=0.001;, score=0.968 total time=   0.2s
# [CV 2/5] END PCA__n_components=0.75, SVM__C=0.001;, score=0.967 total time=   0.2s
# [CV 3/5] END PCA__n_components=0.75, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.75, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.75, SVM__C=0.001;, score=0.968 total time=   0.2s
# [CV 1/5] END PCA__n_components=0.75, SVM__C=0.75075;, score=0.968 total time=   0.2s
# [CV 2/5] END PCA__n_components=0.75, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.75, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.75, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.75, SVM__C=0.75075;, score=0.968 total time=   0.2s
# [CV 1/5] END PCA__n_components=0.75, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.75, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.75, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.75, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.75, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.75, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.75, SVM__C=2.25025;, score=0.967 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.75, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.75, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.75, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.75, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.75, SVM__C=3.0;, score=0.967 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.75, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.75, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.75, SVM__C=3.0;, score=0.968 total time=   0.2s
# [CV 1/5] END PCA__n_components=0.8, SVM__C=0.001;, score=0.968 total time=   0.2s
# [CV 2/5] END PCA__n_components=0.8, SVM__C=0.001;, score=0.967 total time=   0.2s
# [CV 3/5] END PCA__n_components=0.8, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.8, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.8, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.8, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.8, SVM__C=0.75075;, score=0.967 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.8, SVM__C=0.75075;, score=0.968 total time=   0.2s
# [CV 4/5] END PCA__n_components=0.8, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.8, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.8, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.8, SVM__C=1.5005;, score=0.967 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.8, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.8, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.8, SVM__C=1.5005;, score=0.968 total time=   0.2s
# [CV 1/5] END PCA__n_components=0.8, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.8, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.8, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.8, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.8, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 1/5] END .PCA__n_components=0.8, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 2/5] END .PCA__n_components=0.8, SVM__C=3.0;, score=0.967 total time=   0.3s
# [CV 3/5] END .PCA__n_components=0.8, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 4/5] END .PCA__n_components=0.8, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 5/5] END .PCA__n_components=0.8, SVM__C=3.0;, score=0.968 total time=   0.2s
# [CV 1/5] END PCA__n_components=0.85, SVM__C=0.001;, score=0.968 total time=   0.2s
# [CV 2/5] END PCA__n_components=0.85, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.85, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.85, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.85, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.85, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.85, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.85, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.85, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.85, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.85, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.85, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.85, SVM__C=1.5005;, score=0.968 total time=   0.4s
# [CV 4/5] END PCA__n_components=0.85, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.85, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.85, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.85, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.85, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.85, SVM__C=2.25025;, score=0.968 total time=   0.4s
# [CV 5/5] END PCA__n_components=0.85, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.85, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.85, SVM__C=3.0;, score=0.968 total time=   0.2s
# [CV 3/5] END PCA__n_components=0.85, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.85, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.85, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.9, SVM__C=0.001;, score=0.968 total time=   0.4s
# [CV 2/5] END PCA__n_components=0.9, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.9, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.9, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.9, SVM__C=0.001;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.9, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.9, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.9, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.9, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.9, SVM__C=0.75075;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.9, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.9, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.9, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.9, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.9, SVM__C=1.5005;, score=0.968 total time=   0.3s
# [CV 1/5] END PCA__n_components=0.9, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 2/5] END PCA__n_components=0.9, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 3/5] END PCA__n_components=0.9, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 4/5] END PCA__n_components=0.9, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 5/5] END PCA__n_components=0.9, SVM__C=2.25025;, score=0.968 total time=   0.3s
# [CV 1/5] END .PCA__n_components=0.9, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 2/5] END .PCA__n_components=0.9, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 3/5] END .PCA__n_components=0.9, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 4/5] END .PCA__n_components=0.9, SVM__C=3.0;, score=0.968 total time=   0.3s
# [CV 5/5] END .PCA__n_components=0.9, SVM__C=3.0;, score=0.968 total time=   0.3s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', MinMaxScaler()), ('PCA', PCA()),
#                                        ('SVM', SVC(kernel='linear'))]),
#              param_grid={'PCA__n_components': [0.75, 0.8, 0.85, 0.9],
#                          'SVM__C': array([1.00000e-03, 7.50750e-01, 1.50050e+00, 2.25025e+00, 3.00000e+00])},
#              verbose=3)

# %%
print("Best Parameters: ",gcv.best_params_)
print("Best Score: ",gcv.best_score_)
# Out:
# Best Parameters:  {'PCA__n_components': 0.75, 'SVM__C': 0.75075}
# Best Score:  0.9678838296581416
