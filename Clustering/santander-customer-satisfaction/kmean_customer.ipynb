# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

# %%
customer=pd.read_csv("train.csv",index_col=0)
customer.head()
# Out:
#     var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# ID
# 1      2     23                 0.0                      0.0
# 3      2     34                 0.0                      0.0
# 4      2     23                 0.0                      0.0
# 8      2     37                 0.0                    195.0
# 10     2     39                 0.0                      0.0
#
#     imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# ID
# 1                       0.0                      0.0                      0.0
# 3                       0.0                      0.0                      0.0
# 4                       0.0                      0.0                      0.0
# 8                     195.0                      0.0                      0.0
# 10                      0.0                      0.0                      0.0
#
#     imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  imp_op_var40_ult1  ...  \
# ID                                                                       ...
# 1                       0.0                      0.0                0.0  ...
# 3                       0.0                      0.0                0.0  ...
# 4                       0.0                      0.0                0.0  ...
# 8                       0.0                      0.0                0.0  ...
# 10                      0.0                      0.0                0.0  ...
#
#     saldo_medio_var33_hace2  saldo_medio_var33_hace3  saldo_medio_var33_ult1  \
# ID
# 1                       0.0                      0.0                     0.0
# 3                       0.0                      0.0                     0.0
# 4                       0.0                      0.0                     0.0
# 8                       0.0                      0.0                     0.0
# 10                      0.0                      0.0                     0.0
#
#     saldo_medio_var33_ult3  saldo_medio_var44_hace2  saldo_medio_var44_hace3  \
# ID
# 1                      0.0                      0.0                      0.0
# 3                      0.0                      0.0                      0.0
# 4                      0.0                      0.0                      0.0
# 8                      0.0                      0.0                      0.0
# 10                     0.0                      0.0                      0.0
#
#     saldo_medio_var44_ult1  saldo_medio_var44_ult3          var38  TARGET
# ID
# 1                      0.0                     0.0   39205.170000       0
# 3                      0.0                     0.0   49278.030000       0
# 4                      0.0                     0.0   67333.770000       0
# 8                      0.0                     0.0   64007.970000       0
# 10                     0.0                     0.0  117310.979016       0
#
# [5 rows x 370 columns]

# %%
scaler=StandardScaler()
customer_scaled=scaler.fit_transform(customer)

# %%
clust=[2,3,4,5,6,7,8]
scores=[]

# %%
for i in clust:
    km=KMeans(n_clusters=i, random_state=23)
    km.fit(customer_scaled)
    score = silhouette_score(customer_scaled,km.labels_)
    scores.append(score)
# Out:
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
np.max(scores)
# Out:
# 0.6848008845959055

# %%
scores
# Out:
# [0.6812422266829752,
#  0.6848008845959055,
#  0.5850615060640817,
#  0.6008789140257692,
#  0.5162787271374975,
#  0.21473863298462445,
#  0.531301850053537]

# %%
km = KMeans(n_clusters=3,random_state=23)
km.fit(customer_scaled)
# Out:
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3, random_state=23)

# %%
clust_df = customer.copy()
clust_df['Cluster'] = km.labels_
clust_df.sort_values(by='Cluster')
# Out:
#         var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# ID
# 1          2     23                 0.0                     0.00
# 100135     2     35                 0.0                     0.00
# 100132     2     40               300.0                   203.79
# 100125     2     23                 0.0                     0.00
# 100124     2     26                 0.0                     0.00
# ...      ...    ...                 ...                      ...
# 91519      2     71                 0.0                  1074.00
# 124424   161     45                 0.0                  1521.18
# 26392      2     52                 0.0                     0.00
# 43146      2     52                 0.0                  1004.67
# 18508      2     48                 0.0                     0.00
#
#         imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  \
# ID
# 1                          0.00                      0.0
# 100135                     0.00                      0.0
# 100132                   222.84                      0.0
# 100125                     0.00                      0.0
# 100124                     0.00                      0.0
# ...                         ...                      ...
# 91519                   1074.00                      0.0
# 124424                  2188.83                      0.0
# 26392                      0.00                      0.0
# 43146                   1149.42                      0.0
# 18508                      0.00                      0.0
#
#         imp_op_var40_comer_ult3  imp_op_var40_efect_ult1  \
# ID
# 1                           0.0                      0.0
# 100135                      0.0                      0.0
# 100132                      0.0                      0.0
# 100125                      0.0                      0.0
# 100124                      0.0                      0.0
# ...                         ...                      ...
# 91519                       0.0                      0.0
# 124424                      0.0                      0.0
# 26392                       0.0                      0.0
# 43146                       0.0                      0.0
# 18508                       0.0                      0.0
#
#         imp_op_var40_efect_ult3  imp_op_var40_ult1  ...  \
# ID                                                  ...
# 1                           0.0                0.0  ...
# 100135                      0.0                0.0  ...
# 100132                      0.0                0.0  ...
# 100125                      0.0                0.0  ...
# 100124                      0.0                0.0  ...
# ...                         ...                ...  ...
# 91519                       0.0                0.0  ...
# 124424                      0.0                0.0  ...
# 26392                       0.0                0.0  ...
# 43146                       0.0                0.0  ...
# 18508                       0.0                0.0  ...
#
#         saldo_medio_var33_hace3  saldo_medio_var33_ult1  \
# ID
# 1                           0.0                     0.0
# 100135                      0.0                     0.0
# 100132                      0.0                     0.0
# 100125                      0.0                     0.0
# 100124                      0.0                     0.0
# ...                         ...                     ...
# 91519                       0.0                     0.0
# 124424                      0.0                     0.0
# 26392                       0.0                     0.0
# 43146                       0.0                     0.0
# 18508                       0.0                     0.0
#
#         saldo_medio_var33_ult3  saldo_medio_var44_hace2  \
# ID
# 1                          0.0                     0.00
# 100135                     0.0                     0.00
# 100132                     0.0                     0.00
# 100125                     0.0                     0.00
# 100124                     0.0                     0.00
# ...                        ...                      ...
# 91519                      0.0                 19534.11
# 124424                     0.0                  3772.32
# 26392                      0.0                     0.00
# 43146                      0.0                     0.00
# 18508                      0.0                     0.00
#
#         saldo_medio_var44_hace3  saldo_medio_var44_ult1  \
# ID
# 1                          0.00                    0.00
# 100135                     0.00                    0.00
# 100132                     0.00                    0.00
# 100125                     0.00                    0.00
# 100124                     0.00                    0.00
# ...                         ...                     ...
# 91519                      0.00                51666.27
# 124424                   997.62                 3699.24
# 26392                      0.00                    0.00
# 43146                      0.00                    0.00
# 18508                      0.00                 3246.36
#
#         saldo_medio_var44_ult3          var38  TARGET  Cluster
# ID
# 1                         0.00   39205.170000       0        0
# 100135                    0.00   60782.070000       0        0
# 100132                    0.00  117310.979016       0        0
# 100125                    0.00   43974.540000       0        0
# 100124                    0.00   71886.060000       0        0
# ...                        ...            ...     ...      ...
# 91519                 35600.19  117310.979016       0        2
# 124424                 2823.06  245815.950000       0        2
# 26392                     0.00  166835.160000       0        2
# 43146                     0.00  117310.979016       0        2
# 18508                  3246.36  117310.979016       0        2
#
# [76020 rows x 371 columns]

# %%
print(clust_df.groupby(by='Cluster').mean())
# Out:
#              revenue  number_of_orders  recency_days
# Cluster
# 0         692.363868          7.351704    415.639135
# 1        1282.842644         12.923445    133.283442
# 2         750.816010          8.242636    135.709691
